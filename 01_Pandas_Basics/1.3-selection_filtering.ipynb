# %%
import pandas as pd

# %%
songs= pd.read_csv(r"C:\Users\musta\OneDrive\Belgeler\Deneme\spotify_tracks.csv", index_col=1)

# %%
songs.artists
# Out:
# name
# Acoustic                                                                      Billy Raffoul
# Acoustic                                                                      Billy Raffoul
# Here Comes the Sun - Acoustic                                 Molly Hocking, Bailey Rushlow
# Acoustic #3                                                               The Goo Goo Dolls
# My Love Mine All Mine - Acoustic Instrumental                 Guus Dielissen, Casper Esmann
#                                                                     ...
# Voyage to Atlantis                                                       Future World Music
# L'Oiseau                                         Putumayo, Marianne Perrudin, Thomas Artaud
# The Daintree                                                                Joseph Tawadros
# The Sorcerers Symphony                                                   Future World Music
# ...

# %%
songs["artists"]
# Out:
# name
# Acoustic                                                                      Billy Raffoul
# Acoustic                                                                      Billy Raffoul
# Here Comes the Sun - Acoustic                                 Molly Hocking, Bailey Rushlow
# Acoustic #3                                                               The Goo Goo Dolls
# My Love Mine All Mine - Acoustic Instrumental                 Guus Dielissen, Casper Esmann
#                                                                     ...
# Voyage to Atlantis                                                       Future World Music
# L'Oiseau                                         Putumayo, Marianne Perrudin, Thomas Artaud
# The Daintree                                                                Joseph Tawadros
# The Sorcerers Symphony                                                   Future World Music
# ...

# %%
songs["artists"][1500]
# Out:
# C:\Users\musta\AppData\Local\Temp\ipykernel_3748\3277734568.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   songs["artists"][1500]
# 'Skrillex, Sirah'

# %%
songs.iloc[0]
# Out:
# id             7kr3xZk4yb3YSZ4VFtg2Qt
# genre                        acoustic
# artists                 Billy Raffoul
# album                            1975
# popularity                         58
# duration_ms                    172199
# explicit                        False
# Name: Acoustic, dtype: object

# %%
songs.iloc[3:15:3]
# Out:
#                                                      id     genre  \
# name
# Acoustic #3                      1RC9slv335IfLce5vt9KTW  acoustic
# Beautiful Things - Acoustic      3vpJdk93GzerZnlou6Ua0z  acoustic
# Acoustic Energy Vibrations       64zEnxASl3epPAIH4MsmSw  acoustic
# Too Good At Goodbyes - Acoustic  0i49QlMEbbbax1gZe2qQzm  acoustic
#
#                                                                       artists  \
# name
# Acoustic #3                                                 The Goo Goo Dolls
# Beautiful Things - Acoustic                                      Benson Boone
# Acoustic Energy Vibrations       Healing Solfeggio Frequencies, Harmony Touch
# Too Good At Goodbyes - Acoustic                                     Sam Smith
#
#                                                     album  popularity  \
# name
# Acoustic #3                             Dizzy up the Girl          46
# Beautiful Things - Acoustic                      Daydream           0
# ...

# %%
songs.iloc[:3,4]
# Out:
# name
# Acoustic                         58
# Acoustic                         57
# Here Comes the Sun - Acoustic    42
# Name: popularity, dtype: int64

# %%
songs.iloc[[0,1,4,8],4]
# Out:
# name
# Acoustic                                         58
# Acoustic                                         57
# My Love Mine All Mine - Acoustic Instrumental    33
# Acoustic                                         15
# Name: popularity, dtype: int64

# %%
songs.iloc[-5:]
# Out:
#                                             id        genre  \
# name
# Voyage to Atlantis      4uveHSzaz8YEbTF9j6QlCI  world-music
# L'Oiseau                4u15cjyziW2Ewn5Ek3082l  world-music
# The Daintree            56pHPaTeX2O9aVmTFYS8hV  world-music
# The Sorcerers Symphony  6Ldyc5TsR4kaUsuHKcB2AD  world-music
# Fiore d'inverno         3ry0f8ybk8upUBIk8unvmF  world-music
#
#                                                            artists  \
# name
# Voyage to Atlantis                              Future World Music
# L'Oiseau                Putumayo, Marianne Perrudin, Thomas Artaud
# The Daintree                                       Joseph Tawadros
# The Sorcerers Symphony                          Future World Music
# Fiore d'inverno                         Putumayo, Giacomo Lariccia
#
#                                                 album  popularity  \
# name
# Voyage to Atlantis                 Reign of Vengeance          25
# ...

# %%
songs.columns
# Out:
# Index(['id', 'genre', 'artists', 'album', 'popularity', 'duration_ms',
#        'explicit'],
#       dtype='object')

# %%
songs.loc[:, ["genre", "artists","popularity"]]
# Out:
#                                                      genre  \
# name
# Acoustic                                          acoustic
# Acoustic                                          acoustic
# Here Comes the Sun - Acoustic                     acoustic
# Acoustic #3                                       acoustic
# My Love Mine All Mine - Acoustic Instrumental     acoustic
# ...                                                    ...
# Voyage to Atlantis                             world-music
# L'Oiseau                                       world-music
# The Daintree                                   world-music
# The Sorcerers Symphony                         world-music
# Fiore d'inverno                                world-music
#
#                                                                                   artists  \
# name
# Acoustic                                                                    Billy Raffoul
# ...

# %%
songs.set_index("popularity")
# Out:
#                                 id        genre  \
# popularity
# 58          7kr3xZk4yb3YSZ4VFtg2Qt     acoustic
# 57          1kJygfS4eoVziBBI93MSYp     acoustic
# 42          6lynns69p4zTCRxmmiSY1x     acoustic
# 46          1RC9slv335IfLce5vt9KTW     acoustic
# 33          5o9L8xBuILoVjLECSBi7Vo     acoustic
# ...                            ...          ...
# 25          4uveHSzaz8YEbTF9j6QlCI  world-music
# 25          4u15cjyziW2Ewn5Ek3082l  world-music
# 12          56pHPaTeX2O9aVmTFYS8hV  world-music
# 26          6Ldyc5TsR4kaUsuHKcB2AD  world-music
# 25          3ry0f8ybk8upUBIk8unvmF  world-music
#
#                                                artists  \
# popularity
# 58                                       Billy Raffoul
# 57                                       Billy Raffoul
# 42                       Molly Hocking, Bailey Rushlow
# 46                                   The Goo Goo Dolls
# 33                       Guus Dielissen, Casper Esmann
# ...

# %%
songs["popularity"]==80
# Out:
# name
# Acoustic                                         False
# Acoustic                                         False
# Here Comes the Sun - Acoustic                    False
# Acoustic #3                                      False
# My Love Mine All Mine - Acoustic Instrumental    False
#                                                  ...
# Voyage to Atlantis                               False
# L'Oiseau                                         False
# The Daintree                                     False
# The Sorcerers Symphony                           False
# Fiore d'inverno                                  False
# Name: popularity, Length: 6300, dtype: bool

# %%
songs.loc[songs["popularity"]>=90]
# Out:
#                              id genre artists    album  popularity  \
# name
# Houdini  2HYFX63wP3otVIvopRS99Z   edm  Eminem  Houdini          90
#
#          duration_ms  explicit
# name
# Houdini       227239      True

# %%
songs.loc[(songs["genre"]=="edm") & (songs["popularity"]>=75)]
# Out:
#                              id genre artists    album  popularity  \
# name
# Houdini  2HYFX63wP3otVIvopRS99Z   edm  Eminem  Houdini          90
#
#          duration_ms  explicit
# name
# Houdini       227239      True

# %%
songs.loc[(songs["genre"]=="acoustic")| (songs["popularity"]>=75)]
# Out:
#                                                                        id  \
# name
# Acoustic                                           7kr3xZk4yb3YSZ4VFtg2Qt
# Acoustic                                           1kJygfS4eoVziBBI93MSYp
# Here Comes the Sun - Acoustic                      6lynns69p4zTCRxmmiSY1x
# Acoustic #3                                        1RC9slv335IfLce5vt9KTW
# My Love Mine All Mine - Acoustic Instrumental      5o9L8xBuILoVjLECSBi7Vo
# ...                                                                   ...
# Vois sur ton chemin - Techno Mix                   31nfdEooLEq7dn3UMcIeB5
# Trance (with Travis Scott & Young Thug)            5wG3HvLhF6Y5KTGlK0IW3J
# Too Many Nights (feat. Don Toliver & with Future)  2Hh3ETdQKrmSI3QS0hme7g
# I KNOW ?                                           6wsqVwoiVH2kde4k4KKAFU
# Work Out                                           2wAJTrFhCnQyNSD3oUgTZO
#
#                                                       genre  \
# name
# ...

# %%
songs.loc[songs["artists"].isin(["Eminem"])]
# Out:
#                                      id  genre artists  \
# name
# Discombobulated  1oHXeD1gQQCQUYHeHp2HMU  disco  Eminem
# Houdini          2HYFX63wP3otVIvopRS99Z    edm  Eminem
#
#                                                              album  \
# name
# Discombobulated  Music To Be Murdered By - Side B (Deluxe Edition)
# Houdini                                                    Houdini
#
#                  popularity  duration_ms  explicit
# name
# Discombobulated          49       252578      True
# Houdini                  90       227239      True

# %%
songs.loc[songs["album"].notnull()]
# Out:
#                                                                    id  \
# name
# Acoustic                                       7kr3xZk4yb3YSZ4VFtg2Qt
# Acoustic                                       1kJygfS4eoVziBBI93MSYp
# Here Comes the Sun - Acoustic                  6lynns69p4zTCRxmmiSY1x
# Acoustic #3                                    1RC9slv335IfLce5vt9KTW
# My Love Mine All Mine - Acoustic Instrumental  5o9L8xBuILoVjLECSBi7Vo
# ...                                                               ...
# Voyage to Atlantis                             4uveHSzaz8YEbTF9j6QlCI
# L'Oiseau                                       4u15cjyziW2Ewn5Ek3082l
# The Daintree                                   56pHPaTeX2O9aVmTFYS8hV
# The Sorcerers Symphony                         6Ldyc5TsR4kaUsuHKcB2AD
# Fiore d'inverno                                3ry0f8ybk8upUBIk8unvmF
#
#                                                      genre  \
# name
# ...

# %%
songs.loc[songs["duration_ms"].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, genre, artists, album, popularity, duration_ms, explicit]
# Index: []

# %%
songs["id"]=3169
songs.head()
# Out:
#                                                  id     genre  \
# name
# Acoustic                                       3169  acoustic
# Acoustic                                       3169  acoustic
# Here Comes the Sun - Acoustic                  3169  acoustic
# Acoustic #3                                    3169  acoustic
# My Love Mine All Mine - Acoustic Instrumental  3169  acoustic
#
#                                                                      artists  \
# name
# Acoustic                                                       Billy Raffoul
# Acoustic                                                       Billy Raffoul
# Here Comes the Sun - Acoustic                  Molly Hocking, Bailey Rushlow
# Acoustic #3                                                The Goo Goo Dolls
# My Love Mine All Mine - Acoustic Instrumental  Guus Dielissen, Casper Esmann
#
#                                                                                        album  \
# name
# ...

# %%
songs["id"]= range(len(songs),0,-1)
songs.head()
# Out:
#                                                  id     genre  \
# name
# Acoustic                                       6300  acoustic
# Acoustic                                       6299  acoustic
# Here Comes the Sun - Acoustic                  6298  acoustic
# Acoustic #3                                    6297  acoustic
# My Love Mine All Mine - Acoustic Instrumental  6296  acoustic
#
#                                                                      artists  \
# name
# Acoustic                                                       Billy Raffoul
# Acoustic                                                       Billy Raffoul
# Here Comes the Sun - Acoustic                  Molly Hocking, Bailey Rushlow
# Acoustic #3                                                The Goo Goo Dolls
# My Love Mine All Mine - Acoustic Instrumental  Guus Dielissen, Casper Esmann
#
#                                                                                        album  \
# name
# ...

# %%
songs.tail()
# Out:
#                         id        genre  \
# name
# Voyage to Atlantis       5  world-music
# L'Oiseau                 4  world-music
# The Daintree             3  world-music
# The Sorcerers Symphony   2  world-music
# Fiore d'inverno          1  world-music
#
#                                                            artists  \
# name
# Voyage to Atlantis                              Future World Music
# L'Oiseau                Putumayo, Marianne Perrudin, Thomas Artaud
# The Daintree                                       Joseph Tawadros
# The Sorcerers Symphony                          Future World Music
# Fiore d'inverno                         Putumayo, Giacomo Lariccia
#
#                                                 album  popularity  \
# name
# Voyage to Atlantis                 Reign of Vengeance          25
# L'Oiseau                Global Relaxation by Putumayo          25
# The Daintree                              World Music          12
# ...

# %%
songs.describe()
# Out:
#                id   popularity   duration_ms
# count  6300.00000  6300.000000  6.300000e+03
# mean   3150.50000    30.754762  2.028477e+05
# std    1818.79768    19.948991  1.210299e+05
# min       1.00000     0.000000  3.006000e+04
# 25%    1575.75000    16.000000  1.476870e+05
# 50%    3150.50000    29.000000  1.916070e+05
# 75%    4725.25000    45.000000  2.369625e+05
# max    6300.00000    90.000000  3.601658e+06

# %%
songs["artists"].describe()
# Out:
# count          6300
# unique         4651
# top       Metallica
# freq             22
# Name: artists, dtype: object

# %%
songs["popularity"].mean()
# Out:
# np.float64(30.754761904761907)

# %%
songs["artists"].unique()
# Out:
# array(['Billy Raffoul', 'Molly Hocking, Bailey Rushlow',
#        'The Goo Goo Dolls', ..., 'World Music Atelier',
#        'Putumayo, Marianne Perrudin, Thomas Artaud',
#        'Putumayo, Giacomo Lariccia'], shape=(4651,), dtype=object)

# %%
songs["artists"].value_counts()
# Out:
# artists
# Metallica                     22
# ONE OK ROCK                   20
# Chicago House Selection       18
# Death                         17
# Progressive House Sessions    16
#                               ..
# Cody Fry                       1
# SLANDER, Dylan Matthew         1
# Lesfm, Olexy                   1
# The Moon Loungers              1
# BradBrooks, Pamela Bravo       1
# Name: count, Length: 4651, dtype: int64

# %%
pop_mean= songs["popularity"].mean()
songs["popularity"].map(lambda p: p-pop_mean)
# Out:
# name
# Acoustic                                         27.245238
# Acoustic                                         26.245238
# Here Comes the Sun - Acoustic                    11.245238
# Acoustic #3                                      15.245238
# My Love Mine All Mine - Acoustic Instrumental     2.245238
#                                                    ...
# Voyage to Atlantis                               -5.754762
# L'Oiseau                                         -5.754762
# The Daintree                                    -18.754762
# The Sorcerers Symphony                           -4.754762
# Fiore d'inverno                                  -5.754762
# Name: popularity, Length: 6300, dtype: float64

# %%
ms=songs["duration_ms"].mean()
songs["duration_ms"].map(lambda p : p- ms)
# Out:
# name
# Acoustic                                         -30648.735238
# Acoustic                                         -30645.735238
# Here Comes the Sun - Acoustic                    -58061.735238
# Acoustic #3                                      -86274.735238
# My Love Mine All Mine - Acoustic Instrumental    -68925.735238
#                                                      ...
# Voyage to Atlantis                               -22846.735238
# L'Oiseau                                          73928.264762
# The Daintree                                    -133314.735238
# The Sorcerers Symphony                          -112846.735238
# Fiore d'inverno                                  -61047.735238
# Name: duration_ms, Length: 6300, dtype: float64

# %%
songs["genre"]=songs["genre"].apply(lambda t: t.upper())
songs.head()
# Out:
#                                                  id     genre  \
# name
# Acoustic                                       6300  ACOUSTIC
# Acoustic                                       6299  ACOUSTIC
# Here Comes the Sun - Acoustic                  6298  ACOUSTIC
# Acoustic #3                                    6297  ACOUSTIC
# My Love Mine All Mine - Acoustic Instrumental  6296  ACOUSTIC
#
#                                                                      artists  \
# name
# Acoustic                                                       Billy Raffoul
# Acoustic                                                       Billy Raffoul
# Here Comes the Sun - Acoustic                  Molly Hocking, Bailey Rushlow
# Acoustic #3                                                The Goo Goo Dolls
# My Love Mine All Mine - Acoustic Instrumental  Guus Dielissen, Casper Esmann
#
#                                                                                        album  \
# name
# ...

# %%
songs.apply(lambda col: col.max())
# Out:
# id                    6300
# genre          WORLD-MUSIC
# artists                서이브
# album              가자, 밤으로
# popularity              90
# duration_ms        3601658
# explicit              True
# dtype: object

# %%
songs.apply(lambda row: row["popularity"], axis=1)
# Out:
# name
# Acoustic                                         58
# Acoustic                                         57
# Here Comes the Sun - Acoustic                    42
# Acoustic #3                                      46
# My Love Mine All Mine - Acoustic Instrumental    33
#                                                  ..
# Voyage to Atlantis                               25
# L'Oiseau                                         25
# The Daintree                                     12
# The Sorcerers Symphony                           26
# Fiore d'inverno                                  25
# Length: 6300, dtype: int64

# %%
songs["popularity_norm"] = songs["popularity"].apply(
    lambda p: (p - songs["popularity"].mean()) / songs["popularity"].std()
)
songs.head()
# Out:
#                                                  id     genre  \
# name
# Acoustic                                       6300  ACOUSTIC
# Acoustic                                       6299  ACOUSTIC
# Here Comes the Sun - Acoustic                  6298  ACOUSTIC
# Acoustic #3                                    6297  ACOUSTIC
# My Love Mine All Mine - Acoustic Instrumental  6296  ACOUSTIC
#
#                                                                      artists  \
# name
# Acoustic                                                       Billy Raffoul
# Acoustic                                                       Billy Raffoul
# Here Comes the Sun - Acoustic                  Molly Hocking, Bailey Rushlow
# Acoustic #3                                                The Goo Goo Dolls
# My Love Mine All Mine - Acoustic Instrumental  Guus Dielissen, Casper Esmann
#
#                                                                                        album  \
# name
# ...

# %%
songs.loc[(songs["artists"]=="Eminem") | (songs["popularity_norm"]>=2.800000)]
# Out:
#                                                   id   genre  \
# name
# Discombobulated                                 4981   DISCO
# Houdini                                         4733     EDM
# As It Was                                       3503   HOUSE
# One Of The Girls (with JENNIE, Lily Rose Depp)  3142  J-IDOL
# BAND4BAND (feat. Lil Baby)                      1554   R-N-B
# Clean Baby Sleep White Noise (Loopable)          760   SLEEP
#
#                                                                                           artists  \
# name
# Discombobulated                                                                            Eminem
# Houdini                                                                                    Eminem
# As It Was                                                                            Harry Styles
# One Of The Girls (with JENNIE, Lily Rose Depp)                 The Weeknd, JENNIE, Lily-Rose Depp
# ...

# %%
songs["id"].map(lambda p: p-100 if (p-100)>=0 else p)
# Out:
# name
# Acoustic                                         6200
# Acoustic                                         6199
# Here Comes the Sun - Acoustic                    6198
# Acoustic #3                                      6197
# My Love Mine All Mine - Acoustic Instrumental    6196
#                                                  ...
# Voyage to Atlantis                                  5
# L'Oiseau                                            4
# The Daintree                                        3
# The Sorcerers Symphony                              2
# Fiore d'inverno                                     1
# Name: id, Length: 6300, dtype: int64

# %%
df = pd.DataFrame({
    "name": ["Ahmet", "Ayşe", "Mehmet", "Fatma", "Baturalp"],
    "age": [20, 17, 35, 15,28],
    "score": [55, 88, 40, 95,60]
})
df.head()
# Out:
#        name  age  score
# 0     Ahmet   20     55
# 1      Ayşe   17     88
# 2    Mehmet   35     40
# 3     Fatma   15     95
# 4  Baturalp   28     60

# %%
df["Category"] = df["age"].map(
    lambda p: "Kid" if p < 18 else ("Young" if p < 31 else "Adult")
)
df.head()
# Out:
#        name  age  score Category
# 0     Ahmet   20     55    Young
# 1      Ayşe   17     88      Kid
# 2    Mehmet   35     40    Adult
# 3     Fatma   15     95      Kid
# 4  Baturalp   28     60    Young

# %%
df["Result"]=df["score"].apply(
    lambda p: "Pass" if p>60 else ("Fail" if p<60 else "Average-Pass")
)
df.head()
# Out:
#        name  age  score Category        Result
# 0     Ahmet   20     55    Young          Fail
# 1      Ayşe   17     88      Kid          Pass
# 2    Mehmet   35     40    Adult          Fail
# 3     Fatma   15     95      Kid          Pass
# 4  Baturalp   28     60    Young  Average-Pass

# %%
df["Name Len"]= df["name"].apply(
    lambda p: len(p)

)
df.head()
# Out:
#        name  age  score Category        Result  Name Len
# 0     Ahmet   20     55    Young          Fail         5
# 1      Ayşe   17     88      Kid          Pass         4
# 2    Mehmet   35     40    Adult          Fail         6
# 3     Fatma   15     95      Kid          Pass         5
# 4  Baturalp   28     60    Young  Average-Pass         8

# %%
songs_sorted = songs.sort_values("popularity" ,ascending= False)
grouped = songs_sorted.groupby("popularity")
grouped.tail()
# Out:
#                                                       id    genre  \
# name
# Houdini                                             4733      EDM
# Clean Baby Sleep White Noise (Loopable)              760    SLEEP
# As It Was                                           3503    HOUSE
# One Of The Girls (with JENNIE, Lily Rose Depp)      3142   J-IDOL
# BAND4BAND (feat. Lil Baby)                          1554    R-N-B
# ...                                                  ...      ...
# Pra Você Guardei O Amor - Remix                     2353      MPB
# Mania De Você - Dubdogz & Watzgood Remix / Radi...  2352      MPB
# New-Age                                             2350  NEW-AGE
# New-Age                                             2345  NEW-AGE
# Mpb                                                 2376      MPB
#
#                                                                                               artists  \
# name
# ...

# %%
songs.groupby("popularity")["popularity"].count()
# Out:
# popularity
# 0     470
# 1     101
# 2      71
# 3      65
# 4      52
#      ...
# 85      2
# 86      3
# 87      3
# 88      1
# 90      1
# Name: popularity, Length: 90, dtype: int64

# %%
songs.groupby('artists').apply(lambda p: p.genre.iloc[0])
# Out:
# C:\Users\musta\AppData\Local\Temp\ipykernel_3748\721386133.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   songs.groupby('artists').apply(lambda p: p.genre.iloc[0])
# artists
# "Weird Al" Yankovic         ALTERNATIVE
# $anto, Satsu¿                  HARDCORE
# $tupid Young, Mozzy            MANDOPOP
# $uicideboy$, Black Smurf         GERMAN
# (((()))), surround.              TRANCE
#                                ...
# 鈴木 弘                            ROMANCE
# 闻人听書_                          MANDOPOP
# 陶晶瑩                            MANDOPOP
# 黃小琥                            MANDOPOP
# 서이브                               MALAY
# Length: 4651, dtype: object

# %%
songs.groupby("artists")["genre"].first()
# Out:
# artists
# "Weird Al" Yankovic         ALTERNATIVE
# $anto, Satsu¿                  HARDCORE
# $tupid Young, Mozzy            MANDOPOP
# $uicideboy$, Black Smurf         GERMAN
# (((()))), surround.              TRANCE
#                                ...
# 鈴木 弘                            ROMANCE
# 闻人听書_                          MANDOPOP
# 陶晶瑩                            MANDOPOP
# 黃小琥                            MANDOPOP
# 서이브                               MALAY
# Name: genre, Length: 4651, dtype: object

# %%
idx = songs.groupby(['artists', 'genre'])['popularity'].idxmax()
top_songs = songs.loc[idx]
top_songs.head()
# Out:
#                                                       id        genre  \
# name
# The Alternative Polka                               6128  ALTERNATIVE
# Party In the CIA (Parody of "Party In The U.S.A...  2128        PARTY
# RATED R                                             3820     HARDCORE
# Mando (feat. Mozzy)                                 2697     MANDOPOP
# Germantown                                          4300       GERMAN
#
#                                                                      artists  \
# name
# The Alternative Polka                                    "Weird Al" Yankovic
# Party In the CIA (Parody of "Party In The U.S.A...       "Weird Al" Yankovic
# RATED R                                                        $anto, Satsu¿
# Mando (feat. Mozzy)                                      $tupid Young, Mozzy
# Germantown                                          $uicideboy$, Black Smurf
#
# ...

# %%
top_song = songs.sort_values('popularity', ascending=False).groupby(['artists','genre']).first().reset_index()
top_song.head()
# Out:
#                     artists        genre    id  \
# 0       "Weird Al" Yankovic  ALTERNATIVE  6128
# 1       "Weird Al" Yankovic        PARTY  2128
# 2             $anto, Satsu¿     HARDCORE  3820
# 3       $tupid Young, Mozzy     MANDOPOP  2697
# 4  $uicideboy$, Black Smurf       GERMAN  4300
#
#                                     album  popularity  duration_ms  explicit  \
# 0                            Bad Hair Day          34       290906     False
# 1                             Alpocalypse          46       176800     False
# 2                                NEGATIVE          20       123321      True
# 3                              One of One          47       170805      True
# 4  Black $uicide Side C: The Seventh Seal          48       227421      True
#
#    popularity_norm
# 0         0.162677
# 1         0.764211
# 2        -0.539113
# 3         0.814339
# 4         0.864467

# %%
songs.groupby("genre").popularity.agg([len ,min, max])
# Out:
# C:\Users\musta\AppData\Local\Temp\ipykernel_3748\4160941905.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   songs.groupby("genre").popularity.agg([len ,min, max])
# C:\Users\musta\AppData\Local\Temp\ipykernel_3748\4160941905.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   songs.groupby("genre").popularity.agg([len ,min, max])
#              len  min  max
# genre
# ACOUSTIC      50    0   71
# AFROBEAT      50    0   69
# ALT-ROCK      50    0   57
# ALTERNATIVE   50    4   50
# AMBIENT       50    6   62
# ...          ...  ...  ...
# TRANCE        50   15   81
# TRIP-HOP      50    0   67
# ...

# %%
turkey=songs.loc[songs["genre"]=="TURKISH"]
turkey.sort_values(by="popularity", ascending= False)
# Out:
#                                                      id    genre  \
# name
# M.                                                  130  TURKISH
# Şımarık                                             142  TURKISH
# Für Elise                                           139  TURKISH
# Waltz No.2                                          147  TURKISH
# Turkish Cotton                                      149  TURKISH
# Rondo Alla Turca (Turkish March)                    146  TURKISH
# Turkish Coffee                                      145  TURKISH
# Turkish Disco                                       148  TURKISH
# Cascade                                             140  TURKISH
# Turkish March                                       150  TURKISH
# Aşkın Sırrı Bilinmez                                113  TURKISH
# Turkish Song of the Damned                          137  TURKISH
# turkish coffee                                      141  TURKISH
# ...

# %%
xf=songs.groupby(["explicit", "genre"])["artists"].agg(len)
xf
# Out:
# explicit  genre
# False     ACOUSTIC       46
#           AFROBEAT       42
#           ALT-ROCK       44
#           ALTERNATIVE    43
#           AMBIENT        50
#                          ..
# True      TRANCE         16
#           TRIP-HOP        4
#           TURKISH         5
#           WORK-OUT       21
#           WORLD-MUSIC     1
# Name: artists, Length: 249, dtype: int64

# %%
xi = xf.index
type(xi)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
xf.reset_index()
# Out:
#      explicit        genre  artists
# 0       False     ACOUSTIC       46
# 1       False     AFROBEAT       42
# 2       False     ALT-ROCK       44
# 3       False  ALTERNATIVE       43
# 4       False      AMBIENT       50
# ..        ...          ...      ...
# 244      True       TRANCE       16
# 245      True     TRIP-HOP        4
# 246      True      TURKISH        5
# 247      True     WORK-OUT       21
# 248      True  WORLD-MUSIC        1
#
# [249 rows x 3 columns]

# %%
df= songs.groupby("genre").popularity.agg([len ,min, max])
df.sort_values(by="max", ascending= False)
# Out:
# C:\Users\musta\AppData\Local\Temp\ipykernel_3748\1936642135.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df= songs.groupby("genre").popularity.agg([len ,min, max])
# C:\Users\musta\AppData\Local\Temp\ipykernel_3748\1936642135.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df= songs.groupby("genre").popularity.agg([len ,min, max])
#                    len  min  max
# genre
# EDM                 50    0   90
# SLEEP               50   30   88
# J-IDOL              50    7   87
# R-N-B               50    0   87
# HOUSE               50    0   87
# ...                ...  ...  ...
# ...

# %%
df.sort_index()
# Out:
#              len  min  max
# genre
# ACOUSTIC      50    0   71
# AFROBEAT      50    0   69
# ALT-ROCK      50    0   57
# ALTERNATIVE   50    4   50
# AMBIENT       50    6   62
# ...          ...  ...  ...
# TRANCE        50   15   81
# TRIP-HOP      50    0   67
# TURKISH       50    0   67
# WORK-OUT      50    0   76
# WORLD-MUSIC   50    2   51
#
# [126 rows x 3 columns]

# %%
df.sort_values(by=["max", "min"])
# Out:
#                    len  min  max
# genre
# DETROIT-TECHNO      50    0   32
# IRANIAN             50    0   36
# ELECTRONIC          50    0   37
# PROGRESSIVE-HOUSE   50    0   37
# INDUSTRIAL          50    0   39
# ...                ...  ...  ...
# HOUSE               50    0   87
# R-N-B               50    0   87
# J-IDOL              50    7   87
# SLEEP               50   30   88
# EDM                 50    0   90
#
# [126 rows x 3 columns]

# %%
songs.dtypes
# Out:
# id                   int64
# genre               object
# artists             object
# album               object
# popularity           int64
# duration_ms          int64
# explicit              bool
# popularity_norm    float64
# dtype: object

# %%
songs["popularity"].astype("float64")
# Out:
# name
# Acoustic                                         58.0
# Acoustic                                         57.0
# Here Comes the Sun - Acoustic                    42.0
# Acoustic #3                                      46.0
# My Love Mine All Mine - Acoustic Instrumental    33.0
#                                                  ...
# Voyage to Atlantis                               25.0
# L'Oiseau                                         25.0
# The Daintree                                     12.0
# The Sorcerers Symphony                           26.0
# Fiore d'inverno                                  25.0
# Name: popularity, Length: 6300, dtype: float64

# %%
songs.index.dtype
# Out:
# dtype('O')

# %%
songs[pd.isnull(songs["genre"])]
# Out:
# Empty DataFrame
# Columns: [id, genre, artists, album, popularity, duration_ms, explicit, popularity_norm]
# Index: []

# %%
songs[pd.notnull(songs["album"])]
# Out:
#                                                  id        genre  \
# name
# Acoustic                                       6300     ACOUSTIC
# Acoustic                                       6299     ACOUSTIC
# Here Comes the Sun - Acoustic                  6298     ACOUSTIC
# Acoustic #3                                    6297     ACOUSTIC
# My Love Mine All Mine - Acoustic Instrumental  6296     ACOUSTIC
# ...                                             ...          ...
# Voyage to Atlantis                                5  WORLD-MUSIC
# L'Oiseau                                          4  WORLD-MUSIC
# The Daintree                                      3  WORLD-MUSIC
# The Sorcerers Symphony                            2  WORLD-MUSIC
# Fiore d'inverno                                   1  WORLD-MUSIC
#
#                                                                                   artists  \
# name
# ...

# %%
poke= pd.read_csv(r"C:\Users\musta\OneDrive\Belgeler\Deneme\Pokemon.csv")

# %%
poke.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
poke[pd.isnull(poke["Type 2"])]
# Out:
#        #        Name  Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 4      4  Charmander    Fire    NaN    309   39      52       43       60
# 5      5  Charmeleon    Fire    NaN    405   58      64       58       80
# 9      7    Squirtle   Water    NaN    314   44      48       65       50
# 10     8   Wartortle   Water    NaN    405   59      63       80       65
# 11     9   Blastoise   Water    NaN    530   79      83      100       85
# ..   ...         ...     ...    ...    ...  ...     ...      ...      ...
# 775  705     Sliggoo  Dragon    NaN    452   68      75       53       83
# 776  706      Goodra  Dragon    NaN    600   90     100       70      110
# 788  712    Bergmite     Ice    NaN    304   55      69       85       32
# 789  713     Avalugg     Ice    NaN    514   95     117      184       44
# 792  716     Xerneas   Fairy    NaN    680  126     131       95      131
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
poke["Type 2"].fillna("There's not a type 2 value")
# Out:
# 0                          Poison
# 1                          Poison
# 2                          Poison
# 3                          Poison
# 4      There's not a type 2 value
#                   ...
# 795                         Fairy
# 796                         Fairy
# 797                         Ghost
# 798                          Dark
# 799                         Water
# Name: Type 2, Length: 800, dtype: object

# %%
poke["Type 1"].replace("Grass","Wood", inplace= True)
poke.head()
# Out:
# C:\Users\musta\AppData\Local\Temp\ipykernel_3748\3069252413.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   poke["Type 1"].replace("Grass","Wood", inplace= True)
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur   Wood  Poison    318  45      49       49
# 1  2                Ivysaur   Wood  Poison    405  60      62       63
# 2  3               Venusaur   Wood  Poison    525  80      82       83
# ...

# %%
pokew=poke["Type 1"].replace("Grass","Wood")
pokew.head()
# Out:
# 0    Wood
# 1    Wood
# 2    Wood
# 3    Wood
# 4    Fire
# Name: Type 1, dtype: object
